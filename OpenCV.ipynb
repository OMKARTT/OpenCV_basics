# %% [markdown]
# <a href="https://colab.research.google.com/github/OMKARTT/OpenCV_basics/blob/master/OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Mounting Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
#drive.mount('/content/drive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **Importing Libraries**

# %%
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import numpy as np
import glob
import PIL
from PIL import ImageOps
import cv2

# %% [markdown]
# **Reading image and displaying image shape**

# %%
image = cv2.imread('/content/drive/My Drive/CV/Picture/test_image.jpg')
plt.imshow(image)
cols=image.shape[0]
rows=image.shape[1]
print(cols,rows)
# Out:
# 300 480

# %% [markdown]
# **Grayscaling**

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %% [markdown]
# **Cropping the image**

# %%
crop=image[100:400,100:600,:]
plt.imshow(crop)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# **Rotation -Method-1**

# %%
height, width = image.shape[:2]
rotation_matrix = cv2.getRotationMatrix2D((width/2, height/2), 90, .5)
rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))
plt.imshow(rotated_image)

# %% [markdown]
# **Rotation Method-2**

# %%
rotated_image = cv2.transpose(image)
plt.imshow( rotated_image)

# %% [markdown]
# **Horizontal Flip**

# %%
flipped = cv2.flip(image,1)
plt.imshow( flipped)

# %% [markdown]
# **Channel Splitting**

# %%
plt.imshow(image) 

#img[:,:,0]=0 #Blue channel of image
image[:,:,2]=0 #Green channel of image
#img[:,:,2]=0 #Red channel of image

###img[:,:,0]=0 #Blue channel of image
###img[:,:,1]=0 #Green channel of image
##img[:,:,2]=0 #Red channel of image

###img[:,:,0]=0 #Blue channel of image
##img[:,:,1]=0 #Green channel of image
###img[:,:,2]=0 #Red channel of image
plt.imshow(image)

# %% [markdown]
# **Thresholding**

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#ret,thresh1 = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(gray,127,255,cv2.THRESH_BINARY_INV)
#ret,thresh3 = cv2.threshold(gray,127,255,cv2.THRESH_TRUNC)
#ret,thresh4 = cv2.threshold(gray,127,255,cv2.THRESH_TOZERO)
#ret,thresh5 = cv2.threshold(gray,127,255,cv2.THRESH_TOZERO_INV)

#cv2.imshow('image',image)
#cv2.imshow('image - thresh1',thresh1)
plt.imshow(thresh2)
#cv2.imshow('image - thresh3',thresh3)
#cv2.imshow('image - thresh4',thresh4)
#cv2.imshow('image - thresh5',thresh5)

# %% [markdown]
# **Translation**

# %%
height = image.shape[0]
width = image.shape[1]
dimensions = image.shape
quarter_height, quarter_width = height/4, width/4

#       | 1 0 Tx |
#  T  = | 0 1 Ty |

# T is our translation matrix
T = np.float32([[1, 0, quarter_width], [0, 1,quarter_height]])

# We use warpAffine to transform the image using the matrix, T
img_translation = cv2.warpAffine(image, T, (width, height))
plt.imshow( img_translation)
cv2.waitKey()
cv2.destroyAllWindows()
